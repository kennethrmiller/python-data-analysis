# %% [markdown]
# ## Using RandomForestRegressor on the Russian "Troll" Ads dataset.
# This gave some unique insights in what caused people to click on these Russian "troll" ads.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Gathering our data and preparing it for modeling.
# Here I read in the data set, turned some columns into dummy variables so that the model would pick it up more effectively and created a two sets of data, one with only the ad clicks and the other with the predictor variables.

# %%
russiandf = pd.read_csv('russian.afteribm.csv')
russiandf.head(1)
features = pd.get_dummies(russiandf, columns = ['month', 'year'])

# Get rid of column we want to predict
features = features.drop('Ad Clicks ', axis = 1)

features_list = list(features.columns)

# This is the variable we want to predict
labels = np.array(russiandf['Ad Clicks '])

# %% [markdown]
# Check to make sure there are no `NA` values and setting them equal to zero. This works for this data set because the columns in the data set with `NAs` are all dummy columns. This is something that will vary on a case-by-case basis.

# %%
features = np.array(features)

features[np.isnan(features)] = 0
print('Number of NAs', np.isnan(features).sum())
# Out:
# Number of NAs 0

# %% [markdown]
# Here we'll split the data into testing and training on a 70/30 split.

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.30,
                                                                           random_state = 42)

print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (1740, 778)
# Training Labels Shape: (1740,)
# Testing Features Shape: (747, 778)
# Testing Labels Shape: (747,)

# %% [markdown]
# ### Creating a Random Forest model
# Now that the data is split 70/30 into training/test we can create our model. The `n_estimators` is an important variable to watch out for, this is essentially the iterations the model does and with this large of a dataset, things can get slow fast. However, more estimators may improve our results.

# %%
# Instantiate model 
rf = RandomForestRegressor(n_estimators= 100, random_state=13)

# Train the model on training data
rf.fit(train_features, train_labels);

# %% [markdown]
# Looking at our predictions, our mean absolute error is pretty high, suggesting we need to optimize this model. However, the importance of each variable can give us some insights on what causes people to click. We do this below.

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', np.mean(errors))
# Out:
# Mean Absolute Error: 1152.1322076241474

# %% [markdown]
# If we want, we can check how a different number of estimators effect our model. I've demonstrated this below. As we can see, the mean absolute error appears to flatten out after 100. To save time, I'll keep this number of estimators.

# %%
estimator_lst =[1, 10, 50, 100, 150]
for element in estimator_lst:
    rftest = RandomForestRegressor(n_estimators= element, random_state=13)
    rftest.fit(train_features, train_labels)
    errors = abs(rftest.predict(test_features) - test_labels)

    print(element, ': Mean Absolute Error:', np.mean(errors))
# Out:
# 1 : Mean Absolute Error: 1797.838464970995
# 10 : Mean Absolute Error: 1233.21270638108
# 50 : Mean Absolute Error: 1160.8072744948047
# 100 : Mean Absolute Error: 1152.1322076241474
# 150 : Mean Absolute Error: 1152.9307778627738

# %% [markdown]
# Next we'll see what features are most important for our first model. Remember, `rf` is our original model with 100 estimators. As expected, `Ad Spend` has the highest effect on clicks. This makes sense because the more costly ads most likely reached more people. The `Age:.16-65+` is an unfortunate marker, as it includes nearly the entire population. This shows us that perhaps we should remove this variable and look for more informative age markers. From this list, we see that explicit ads and ads trigger emotional responses from people garnered the most clicks, which befit's their name of "troll ads".

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 4)) for feature, importance in zip(features_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Ad Spend             Importance: 0.482
# Variable: Age:.16-65+          Importance: 0.0427
# Variable: Mexico.LaRaza        Importance: 0.0312
# Variable: Interests:.MartinLutherKingIII Importance: 0.0244
# Variable: word_count           Importance: 0.017
# Variable: facet_gregariousness Importance: 0.0155
# Variable: Mexico.BeingChicano.Mexicanamericanculture Importance: 0.0142
# Variable: facet_cooperation    Importance: 0.0139
# Variable: need_structure       Importance: 0.0129
# Variable: OBSCENE              Importance: 0.012
# Variable: mm_yyyy_2_2017       Importance: 0.011
# Variable: SEXUALLY_EXPLICIT    Importance: 0.0105
# Variable: Mexico.Latinhiphop.Chicano Importance: 0.0102
# Variable: month_2              Importance: 0.01
# Variable: facet_dutifulness    Importance: 0.0097
# Variable: big5_openness        Importance: 0.0088
# Variable: value_openness_to_change Importance: 0.0087
# Variable: ATTACK_ON_AUTHOR     Importance: 0.0081
# Variable: facet_imagination    Importance: 0.0075
# Variable: value_hedonism       Importance: 0.007
# Variable: SEVERE_TOXICITY      Importance: 0.0069
# Variable: need_closeness       Importance: 0.0068
# Variable: big5_extraversion    Importance: 0.0066
# Variable: TOXICITY             Importance: 0.0061
# Variable: need_self_expression Importance: 0.0061
# Variable: value_self_transcendence Importance: 0.0059
# Variable: facet_modesty        Importance: 0.0058
# Variable: FLIRTATION           Importance: 0.0056
# Variable: facet_intellect      Importance: 0.0056
# Variable: INSULT               Importance: 0.0053
# Variable: facet_self_discipline Importance: 0.0053
# Variable: THREAT               Importance: 0.0052
# Variable: facet_emotionality   Importance: 0.0051
# Variable: need_harmony         Importance: 0.0049
# Variable: facet_friendliness   Importance: 0.0048
# Variable: facet_self_consciousness Importance: 0.0046
# Variable: need_love            Importance: 0.0046
# Variable: big5_agreeableness   Importance: 0.0044
# Variable: facet_artistic_interests Importance: 0.0044
# Variable: INCOHERENT           Importance: 0.0041
# Variable: need_curiosity       Importance: 0.0041
# Variable: INFLAMMATORY         Importance: 0.004
# Variable: Mexico.Chicanorap    Importance: 0.004
# Variable: Interests:.Blacknationalism Importance: 0.004
# Variable: need_stability       Importance: 0.0039
# Variable: facet_self_efficacy  Importance: 0.0036
# Variable: facet_adventurousness Importance: 0.0036
# Variable: Mexico.Lowrider      Importance: 0.0034
# Variable: facet_excitement_seeking Importance: 0.0034
# Variable: facet_liberalism     Importance: 0.0034
# Variable: value_self_enhancement Importance: 0.0034
# Variable: PROFANITY            Importance: 0.0032
# Variable: facet_orderliness    Importance: 0.0032
# Variable: facet_immoderation   Importance: 0.003
# Variable: facet_trust          Importance: 0.0029
# Variable: need_ideal           Importance: 0.0029
# Variable: Interests:.Policeofficer Importance: 0.0028
# Variable: big5_neuroticism     Importance: 0.0028
# Variable: need_challenge       Importance: 0.0028
# Variable: IDENTITY_ATTACK      Importance: 0.0027
# Variable: Placements:.Rightcolumnondesktopcomputers Importance: 0.0027
# Variable: facet_activity_level Importance: 0.0026
# Variable: facet_sympathy       Importance: 0.0025
# Variable: facet_cautiousness   Importance: 0.0025
# Variable: facet_anxiety        Importance: 0.0025
# Variable: need_practicality    Importance: 0.0025
# Variable: Interests:.Gaypride  Importance: 0.0023
# Variable: facet_achievement_striving Importance: 0.0022
# Variable: Location - Living In:.UnitedStates Importance: 0.0021
# Variable: facet_morality       Importance: 0.0021
# Variable: big5_conscientiousness Importance: 0.0021
# Variable: facet_vulnerability  Importance: 0.0021
# Variable: ATTACK_ON_COMMENTER  Importance: 0.002
# Variable: facet_anger          Importance: 0.002
# Variable: facet_depression     Importance: 0.0018
# Variable: mm_yyyy_6_2015       Importance: 0.0018
# Variable: facet_cheerfulness   Importance: 0.0017
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoDon'tShoot Importance: 0.0016
# Variable: need_excitement      Importance: 0.0016
# Variable: facet_altruism       Importance: 0.0014
# Variable: facet_assertiveness  Importance: 0.0014
# Variable: People Who Match:.PeoplewholikeDon'tShoot Importance: 0.0013
# Variable: value_conservation   Importance: 0.0013
# Variable: need_liberty         Importance: 0.0011
# Variable: Exclude people who like.SouthUnited Importance: 0.001
# Variable: mm_yyyy_3_2017       Importance: 0.0009
# Variable: year_2017            Importance: 0.0008
# Variable: People Who Match:.African-AmericanCivilRightsMovement(1954-68) Importance: 0.0007
# Variable: Interests:.Statepolice Importance: 0.0007
# Variable: month_4              Importance: 0.0007
# Variable: Interests:.MalcolmX  Importance: 0.0005
# Variable: Language:.English(US) Importance: 0.0005
# Variable: mm_yyyy_10_2016      Importance: 0.0005
# Variable: mm_yyyy_4_2016       Importance: 0.0005
# Variable: year_2016            Importance: 0.0005
# Variable: Interests:.LOL       Importance: 0.0004
# Variable: Age:.14-40           Importance: 0.0004
# Variable: month_5              Importance: 0.0004
# Variable: Interests:.Jr.;African-AmericanCivilRightsMovement(1954-68) Importance: 0.0003
# Variable: Interests:.LGBTsocialmovements Importance: 0.0003
# Variable: Interests:.ConfederateFlag Importance: 0.0003
# Variable: Location:.UnitedStates Importance: 0.0003
# Variable: Interests:.MartinLutherKing Importance: 0.0003
# Variable: Language:.English(UK)orEnglish(US) Importance: 0.0003
# Variable: Interests:.African-AmericanCivilRightsMovement(1954-68) Importance: 0.0003
# Variable: Interests:.LGBTculture Importance: 0.0003
# Variable: mm_yyyy_4_2017       Importance: 0.0003
# Variable: mm_yyyy_5_2017       Importance: 0.0003
# Variable: month_10             Importance: 0.0003
# Variable: Age:.18-65+          Importance: 0.0002
# Variable: Interests:.Lawenforcement Importance: 0.0002
# Variable: Interests:.FunnyPics Importance: 0.0002
# Variable: Placements:.NewsFeedondesktopcomputers Importance: 0.0002
# Variable: Interests:.SouthernPride Importance: 0.0002
# Variable: Age:.18-50           Importance: 0.0002
# Variable: Interests:.FunnyPictures Importance: 0.0002
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoBlackMatters Importance: 0.0002
# Variable: Interests:.African-Americanhistory Importance: 0.0002
# Variable: Interests:.Jr.       Importance: 0.0002
# Variable: Interests:.NationalAssociationforGunRights Importance: 0.0002
# Variable: police               Importance: 0.0002
# Variable: mm_yyyy_5_2016       Importance: 0.0002
# Variable: month_3              Importance: 0.0002
# Variable: Interests:.iFunny    Importance: 0.0001
# Variable: Interests:.AfricanAmericanculture Importance: 0.0001
# Variable: People Who Match:.PeoplewholikeBlackMatters. Importance: 0.0001
# Variable: Interests:.MexicanAmericanPride Importance: 0.0001
# Variable: Interests:.LaRaza    Importance: 0.0001
# Variable: Interests:.African-Americanculture Importance: 0.0001
# Variable: Placements:.NewsFeedonmobiledevices Importance: 0.0001
# Variable: Exclude people who like.BlackMatters Importance: 0.0001
# Variable: Interests:.St.Louis  Importance: 0.0001
# Variable: Interests:.MexicanPride Importance: 0.0001
# Variable: Interests:.Safety    Importance: 0.0001
# Variable: Interests:.BlackConsciousnessMovement Importance: 0.0001
# Variable: Placements:.Third-partyAppsandWebsitesonmobiledevices Importance: 0.0001
# Variable: Interests:.Socialjustice Importance: 0.0001
# Variable: Exclude people who like.Defendthe2nd Importance: 0.0001
# Variable: Exclude people who like.BM Importance: 0.0001
# Variable: Interests:.StopRacism!! Importance: 0.0001
# Variable: Interests:.ConfederateStatesofAmerica Importance: 0.0001
# Variable: Interests:.Jr.;African-Americanculture Importance: 0.0001
# Variable: Interests:.SoMexican Importance: 0.0001
# Variable: Exclude people who like.HeartofTexas Importance: 0.0001
# Variable: Interests:.Jr..StopRacism!!.AfricanAmericanculture.African-AmericanCivilRightsMovement(1954-68) Importance: 0.0001
# Variable: Mexico.Latinhiphop   Importance: 0.0001
# Variable: People Who Match:.PeoplewholikeBlackMatters Importance: 0.0001
# Variable: Interests:.FunnyPhoto's Importance: 0.0001
# Variable: Interests:.African-AmericanCivilRightsMovement(1954-68).African-Americanhistory Importance: 0.0001
# Variable: Exclude people who like.WokeBlacks Importance: 0.0001
# Variable: Interests:.SayToNoRacism Importance: 0.0001
# Variable: Interests:.AfricanAmericanhistory Importance: 0.0001
# Variable: black                Importance: 0.0001
# Variable: innocent             Importance: 0.0001
# Variable: supremacist          Importance: 0.0001
# Variable: mm_yyyy_11_2015      Importance: 0.0001
# Variable: mm_yyyy_11_2016      Importance: 0.0001
# Variable: mm_yyyy_2_2016       Importance: 0.0001
# Variable: mm_yyyy_7_2016       Importance: 0.0001
# Variable: month_11             Importance: 0.0001
# Variable: year_2015            Importance: 0.0001
# Variable: Interests:.GunOwnersofAmerica Importance: 0.0
# Variable: Interests:.ElectionsintheUnitedStates Importance: 0.0
# Variable: Interests:.Justice   Importance: 0.0
# Variable: Interests:.Policecorruption Importance: 0.0
# Variable: Interests:.NativeAmericanIndianWisdom Importance: 0.0
# Variable: Interests:.ConservativeTribune Importance: 0.0
# Variable: Behaviors:.Smallbusinessowners Importance: 0.0
# Variable: Language:.Spanish    Importance: 0.0
# Variable: Interests:.LiberalDemocrats Importance: 0.0
# Variable: Interests:.Amenity   Importance: 0.0
# Variable: Job title:.Soldado   Importance: 0.0
# Variable: Mexico.Hispanidad    Importance: 0.0
# Variable: Age:.25-65+          Importance: 0.0
# Variable: People Who Match:.InterestsMartinLutherKing Importance: 0.0
# Variable: Interests:.VeteransForAmerica Importance: 0.0
# Variable: Affinity:.AfricanAmerican(US) Importance: 0.0
# Variable: Interests:.MuslimsforAmerica Importance: 0.0
# Variable: Behaviors:.AfricanAmerican(US)orAsianAmerican(US) Importance: 0.0
# Variable: Interests:.Policemisconduct Importance: 0.0
# Variable: Mexico.Chicano       Importance: 0.0
# Variable: United States:.Houston(+10mi)Texas Importance: 0.0
# Variable: Interests:.motherjones. Importance: 0.0
# Variable: Interests:.HueyP.Newton Importance: 0.0
# Variable: United States:.NewYork(+40km)NewYork Importance: 0.0
# Variable: Interests:.Reddit    Importance: 0.0
# Variable: Interests:.UnionofHuffingtonPostWritersandBloggers Importance: 0.0
# Variable: Interests:.SelfDefenseFamily Importance: 0.0
# Variable: Interests:.Police    Importance: 0.0
# Variable: Interests:.Sharia    Importance: 0.0
# Variable: Exclude people who like.VeteransComeFirst Importance: 0.0
# Variable: Interests:.BlackWomenAreBeautiful Importance: 0.0
# Variable: Interests:.Deportation Importance: 0.0
# Variable: Interests:.Socialdemocracy Importance: 0.0
# Variable: Interests:.BillO'Reilly(politicalcommentator) Importance: 0.0
# Variable: Interests:.BlackKnowledge Importance: 0.0
# Variable: Employers:.U.S.ArmyReserve Importance: 0.0
# Variable: Interests:.Classicalliberalism Importance: 0.0
# Variable: Language:.English(UK) Importance: 0.0
# Variable: Interests:.SouthernUnitedStates Importance: 0.0
# Variable: Behaviors:.AfricanAmerican(US) Importance: 0.0
# Variable: Interests:.Violenceprevention Importance: 0.0
# Variable: Interests:.Africanculture Importance: 0.0
# Variable: Interests:.PanAfricanistCongressofAzania Importance: 0.0
# Variable: Mexico.Latinoculture Importance: 0.0
# Variable: Interests:.Self-defense Importance: 0.0
# Variable: Age:.18-48           Importance: 0.0
# Variable: Exclude people who like.WatchthePolice Importance: 0.0
# Variable: Interests:.ChristopherHitchens Importance: 0.0
# Variable: Interests:.Vevo      Importance: 0.0
# Variable: Interests:.Broad-BasedBlackEconomicEmpowerment Importance: 0.0
# Variable: Interests:.VeteransDay Importance: 0.0
# Variable: Interests:.CherokeeNation Importance: 0.0
# Variable: Interests:.HillaryClinton Importance: 0.0
# Variable: Interests:.2ndAmendment Importance: 0.0
# Variable: Interests:.MartinLutherKing;Jr. Importance: 0.0
# Variable: People Who Match:.PeoplewholikeUnitedMuslimsofAmerica Importance: 0.0
# Variable: Interests:.Supportourtroops Importance: 0.0
# Variable: United States:.LosAngeles(+50mi)California Importance: 0.0
# Variable: Interests:.Same-sexmarriage Importance: 0.0
# Variable: Age:.21-65+          Importance: 0.0
# Variable: Interests:.TeaPartyPatriots Importance: 0.0
# Variable: Interests:.Guns.com  Importance: 0.0
# Variable: Interests:.TheWomen'sSelfDefenseInstitute Importance: 0.0
# Variable: United States:.SanFrancisco(+25mi)California;Madison(+25mi)Wisconsin Importance: 0.0
# Variable: Interests:.SupportOurVeterans Importance: 0.0
# Variable: Age:.19-30           Importance: 0.0
# Variable: Interests:.KnowingJesus Importance: 0.0
# Variable: Interests:.lmgur     Importance: 0.0
# Variable: Interests:.LauraIngraham Importance: 0.0
# Variable: Exclude people who like.Williams&Kalvin Importance: 0.0
# Variable: Interests:.RonPaul   Importance: 0.0
# Variable: Interests:.Motherhood Importance: 0.0
# Variable: Interests:.Muhammad  Importance: 0.0
# Variable: People Who Match:.StopPoliceBrutality Importance: 0.0
# Variable: Age:.30-65+          Importance: 0.0
# Variable: Interests:.AngelaDavis Importance: 0.0
# Variable: Interests:.SlaveryintheUnitedStates Importance: 0.0
# Variable: Interests:.IslamintheUnitedStates Importance: 0.0
# Variable: Interests:.Syria     Importance: 0.0
# Variable: Mexico.Mexicanamericanculture Importance: 0.0
# Variable: Interests:.ConcealedcarryintheUnitedStates Importance: 0.0
# Variable: Exclude people who like.NativeAmericansUnited Importance: 0.0
# Variable: United States:.Atlanta(+20km)Georgia;Baltimore(+20km)Maryland;St.Louis(+50km)Missouri;Richmond(+20km)Virginia Importance: 0.0
# Variable: Age:.13-60           Importance: 0.0
# Variable: Exclude people who like.StopA.1. Importance: 0.0
# Variable: Interests:.AmericanGuns Importance: 0.0
# Variable: People Who Match:.PeoplewholikeBeingPatriotic Importance: 0.0
# Variable: Interest expansion:.On Importance: 0.0
# Variable: Interests:.Color     Importance: 0.0
# Variable: Age:.18-61           Importance: 0.0
# Variable: Interests:.MalcolmXGrassrootsMovement Importance: 0.0
# Variable: Interests:.BLACKBUSINESSGLOBAL Importance: 0.0
# Variable: Age:.13-35           Importance: 0.0
# Variable: United States:.Kansas Importance: 0.0
# Variable: Interests:.Guns&Ammo Importance: 0.0
# Variable: Exclude people who like.BeingPatriotic Importance: 0.0
# Variable: Age:.13-40           Importance: 0.0
# Variable: Interests:.RedneckNation Importance: 0.0
# Variable: Exclude people who like.Black—Baptist—church Importance: 0.0
# Variable: Interests:.Humour    Importance: 0.0
# Variable: Interests:.CollegeHumor Importance: 0.0
# Variable: Interests:.FailBlog  Importance: 0.0
# Variable: Job title:.Veteran   Importance: 0.0
# Variable: Interests:.MuslimsAreNotTerrorists Importance: 0.0
# Variable: Interests:.Martialarts Importance: 0.0
# Variable: Exclude people who like.BornLiberal Importance: 0.0
# Variable: Age:.13-45           Importance: 0.0
# Variable: School:.CaliforniaStateUniversity Importance: 0.0
# Variable: Industry:.Veterans(US) Importance: 0.0
# Variable: Gender:.Male         Importance: 0.0
# Variable: Exclude people who like.BlackExcellence Importance: 0.0
# Variable: Interests:.MalcolmXMemorialFoundation Importance: 0.0
# Variable: Interests:.LGBTrightsbycountry Importance: 0.0
# Variable: Interests:.Mecca     Importance: 0.0
# Variable: Custom Audience:.Lookalike(US Importance: 0.0
# Variable: Location - Living In:.UnitedStatesConnections:PeoplewholikeUnitedMuslimsofAmerica Importance: 0.0
# Variable: Age:.16-45           Importance: 0.0
# Variable: Location - Living In:.UnitedStatesConnections:PeoplewholikeBeingPatriotic Importance: 0.0
# Variable: Interests:.SoundCloud Importance: 0.0
# Variable: Interests:.Islamism  Importance: 0.0
# Variable: Interests:.Christianity Importance: 0.0
# Variable: Age:.13-44           Importance: 0.0
# Variable: Politics:.USpolitics(conservative) Importance: 0.0
# Variable: Interests:.RacismintheUnitedStates Importance: 0.0
# Variable: Interests:.Hispanicandlatinoamericanculture Importance: 0.0
# Variable: Interests:.OldGlory  Importance: 0.0
# Variable: Interests:.Society   Importance: 0.0
# Variable: United States:.LosAngeles(+25mi)California Importance: 0.0
# Variable: Interests:.BlackPower Importance: 0.0
# Variable: Interests:.MichaelSavage Importance: 0.0
# Variable: Interests:.Baltimore Importance: 0.0
# Variable: Interests:.HuffPostPolitics Importance: 0.0
# Variable: Mexico.BeingChicano  Importance: 0.0
# Variable: People Who Match:.BlackConsciousnessMovement.MartinLutherKingIII Importance: 0.0
# Variable: Interests:.ProudtobeanAmerican Importance: 0.0
# Variable: Interests:.FightthePower Importance: 0.0
# Variable: Interests:.RushLimbaugh Importance: 0.0
# Variable: Language:.English(US)orSpanish(Spain) Importance: 0.0
# Variable: Interests:.jesusloveu Importance: 0.0
# Variable: Interests:.TheAfricanHistoryNetwork Importance: 0.0
# Variable: Interests:.Culture   Importance: 0.0
# Variable: Age:.18-51           Importance: 0.0
# Variable: Interests:.9GAG      Importance: 0.0
# Variable: Location:.UnitedKingdom Importance: 0.0
# Variable: Age:.16-25           Importance: 0.0
# Variable: Interests:.AfricanAmericanCivilRightsMovement(1954-68) Importance: 0.0
# Variable: Interests:.Freckle   Importance: 0.0
# Variable: Interests:.TheInvaders Importance: 0.0
# Variable: Interests:.Veterans  Importance: 0.0
# Variable: Interests:.Jr.;African-AmericanCivilRightsMovement(1954-68).African-Americanhistory Importance: 0.0
# Variable: Interests:.IraqandAfghanistanVeteransofAmerica Importance: 0.0
# Variable: Interests:.territory Importance: 0.0
# Variable: Interests:.Melanin   Importance: 0.0
# Variable: United States:.NewOrleans(+25mi)Louisiana;Baltimore(+25mi)Maryland;St.Louis(+25mi)Missouri;Camden(+25mi) Importance: 0.0
# Variable: United States:.NewYork(+25mi)NewYork Importance: 0.0
# Variable: Interests:.PolicebrutalityintheUnitedStates Importance: 0.0
# Variable: Interests:.MayaAngelou Importance: 0.0
# Variable: Age:.18-59           Importance: 0.0
# Variable: United States:.St.Louis(+20km)Missouri;Virginia Importance: 0.0
# Variable: Interests:.AntelopeValleyCollege Importance: 0.0
# Variable: Age:.18-55           Importance: 0.0
# Variable: United States:.Astoria(+50mi)NewYork Importance: 0.0
# Variable: Interests:.YoungRepublicans Importance: 0.0
# Variable: Interests:.Imgur     Importance: 0.0
# Variable: United States:.Oakland(+25mi)California;Atlanta(+25mi)Georgia;BatonRouge(+25mi) Importance: 0.0
# Variable: Interests:.JesusDaily Importance: 0.0
# Variable: Interests:.BlackPower.Racialequality Importance: 0.0
# Variable: Interests:.TheTeaParty Importance: 0.0
# Variable: Age:.16-60           Importance: 0.0
# Variable: Interests:.AmericanIndianMovement Importance: 0.0
# Variable: Interests:.Nationalidentity Importance: 0.0
# Variable: Interests:.VietnamVeteransofAmericaFoundation Importance: 0.0
# Variable: Industry:.Military(Global) Importance: 0.0
# Variable: People Who Match:.Black(Color) Importance: 0.0
# Variable: People Who Match:.PeoplewholikeBornLiberal Importance: 0.0
# Variable: Interests:.BlackHistoryMonth Importance: 0.0
# Variable: United States:.SouthCarolina Importance: 0.0
# Variable: Interests:.MartinLutherKingIll Importance: 0.0
# Variable: Interests:.SupportingOurVeterans Importance: 0.0
# Variable: United States:.Oakland(+50mi)Maryland;Ferguson(+50mi) Importance: 0.0
# Variable: Age:.1865+           Importance: 0.0
# Variable: Interests:.Internetmeme Importance: 0.0
# Variable: Affinity:.Hispanic(US-Bilingual) Importance: 0.0
# Variable: Job title:.Polisimiliter Importance: 0.0
# Variable: Interests:.ConfederateStatesArmy Importance: 0.0
# Variable: Interests:.DonaldTrump Importance: 0.0
# Variable: Interests:.Muslimworld Importance: 0.0
# Variable: Affinity:.Hispanic(US-Englishdominant) Importance: 0.0
# Variable: People Who Match:.PeoplewholikeStopA.I. Importance: 0.0
# Variable: Interests:.PersonalDefense Importance: 0.0
# Variable: Mexico..Hispanidad   Importance: 0.0
# Variable: Interests:.BlackBusinessWorks Importance: 0.0
# Variable: Interests:.MahatmaGandhi Importance: 0.0
# Variable: United States:.Lancaster(+25mi) Importance: 0.0
# Variable: Interests:.TheSelfDefenseCompany Importance: 0.0
# Variable: Age:.18-45           Importance: 0.0
# Variable: And Must Also Match:.Multicultural Importance: 0.0
# Variable: Age:.13-65+          Importance: 0.0
# Variable: Behaviors:.Hispanic(US-All) Importance: 0.0
# Variable: Interests:.MumiaAbu-Jamal Importance: 0.0
# Variable: Interests:.Blackhistory Importance: 0.0
# Variable: Interests:.2016      Importance: 0.0
# Variable: Interests:.Bible     Importance: 0.0
# Variable: Interests:.Spotify   Importance: 0.0
# Variable: Interests:.Socialmovement Importance: 0.0
# Variable: United States:.AtlantaGeorgia Importance: 0.0
# Variable: Custom Audience:.1%)-PeoplewholikeDefendthe2nd Importance: 0.0
# Variable: United States:.BaltimoreMaryland:Ferguson Importance: 0.0
# Variable: Interests:.Islam     Importance: 0.0
# Variable: Interests:.African-AmericanCivilRightsMovement(1954--68) Importance: 0.0
# Variable: Interests:.RepublicanParty(UnitedStates) Importance: 0.0
# Variable: Interests:.Immigrationlaw Importance: 0.0
# Variable: Politics:.Likelytoengagewithpoliticalcontent(liberal) Importance: 0.0
# Variable: United States:.St.Louis(+50mi)Missouri;Milwaukee(+25mi)Wisconsin Importance: 0.0
# Variable: Interests:.ImmigrationtotheUnitedStates Importance: 0.0
# Variable: Interests:.Dixie     Importance: 0.0
# Variable: Language:.English(US)PlacementsNewsFeedondesktopcomputers Importance: 0.0
# Variable: United States:.St.LouisMissouri;ClevelandOhio Importance: 0.0
# Variable: United States:.Baltimore(+25mi)Maryland Importance: 0.0
# Variable: Interests:.BlackEconomicEmpowerment Importance: 0.0
# Variable: Interests:.Family    Importance: 0.0
# Variable: United States:.Atlanta(+25mi)Georgia;NewOrleans(+25mi)Louisiana;Baltimore(+25mi)Maryland;St.Louis(+25mi)Missouri;Cleveland(+25mi)Ohio Importance: 0.0
# Variable: Language:.English(UK);Arabic Importance: 0.0
# Variable: Exclude people who like.SecuredBorders Importance: 0.0
# Variable: Interests:.Freemarket Importance: 0.0
# Variable: Interests:.ITunes    Importance: 0.0
# Variable: Interests:.NationalRifleAssociation Importance: 0.0
# Variable: Interests:.Civilandpoliticalrights Importance: 0.0
# Variable: People Who Match:.InterestsBlacknationalism Importance: 0.0
# Variable: Interests:.Last.fm   Importance: 0.0
# Variable: School:.EastBayContinuingEducation Importance: 0.0
# Variable: Interests:.Freesoftware Importance: 0.0
# Variable: People Who Match:.InterestsPan-Africanism Importance: 0.0
# Variable: Exclude people who like.StopRefugees Importance: 0.0
# Variable: And Must Also Match:.SoundCloud Importance: 0.0
# Variable: Interests:.Grooveshark Importance: 0.0
# Variable: Behaviors:.AsianAmerican(US) Importance: 0.0
# Variable: Mexico.BeingMexican  Importance: 0.0
# Variable: United States:.NewYork Importance: 0.0
# Variable: Age:.14-65+          Importance: 0.0
# Variable: Interests:.Humanrights Importance: 0.0
# Variable: Interests:.IndianCountryTodayMediaNetwork Importance: 0.0
# Variable: Interests:.Black(Color) Importance: 0.0
# Variable: Interests:.Minarchism Importance: 0.0
# Variable: Exclude people who like.UnitedMuslimsofAmerica Importance: 0.0
# Variable: School:.UniversityofCalifornia Importance: 0.0
# Variable: Interests:.BlackEnterpriseBusinessReport Importance: 0.0
# Variable: Exclude people who like.Memopolis Importance: 0.0
# Variable: And Must Also Match:.InterestsMusic;Last.fm Importance: 0.0
# Variable: United States:.Atlanta(+20km)Georgia;Maryland;Ferguson(+20km) Importance: 0.0
# Variable: Interests:.SeanHannity Importance: 0.0
# Variable: Age:.15-25           Importance: 0.0
# Variable: Interests:.Pentecostalism Importance: 0.0
# Variable: Interests:.InnocenceProject Importance: 0.0
# Variable: Age:.35-65+          Importance: 0.0
# Variable: Mexico..Latinhiphop.ChicanoMovement Importance: 0.0
# Variable: Custom Audience:.I%)-newtestaudit Importance: 0.0
# Variable: United States:.Baltimore(+20km)Maryland;St.Louis(+20km)Missouri Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoBeingPatriotic Importance: 0.0
# Variable: Behaviors:.Hispanic(US-Englishdominant) Importance: 0.0
# Variable: Interests:.AfricanAmerican Importance: 0.0
# Variable: Interests:.Humanitarianaid Importance: 0.0
# Variable: Interests:.MikeHuckabee Importance: 0.0
# Variable: Interests:.FilmingCops Importance: 0.0
# Variable: Interests:.Prisonreform Importance: 0.0
# Variable: Placements:.lnstagramFeed Importance: 0.0
# Variable: Exclude people who like.Black4Black Importance: 0.0
# Variable: Interests:.Meme      Importance: 0.0
# Variable: on pages:.NewsFeedondesktopcomputers Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoUnitedMuslimsofAmerica Importance: 0.0
# Variable: Interests:.Anti-racism Importance: 0.0
# Variable: Location:.France     Importance: 0.0
# Variable: Interests:.Cultureof Importance: 0.0
# Variable: Interests:.IHaveDecidedtoFollowJesus Importance: 0.0
# Variable: Interests:.Liberalism Importance: 0.0
# Variable: Interests:.Visualperception Importance: 0.0
# Variable: Mexico.MexicanPride  Importance: 0.0
# Variable: United States:.Charlotte(+25mi)NorthCarolina Importance: 0.0
# Variable: Interests:.Right-wingpolitics Importance: 0.0
# Variable: Interests:.LibertarianParty(UnitedStates) Importance: 0.0
# Variable: Interests:.IHaveaDream Importance: 0.0
# Variable: Age:.NewsFeedonmobiledevices Importance: 0.0
# Variable: Exclude:.Hispanic(US-Englishdominant) Importance: 0.0
# Variable: People Who Match:.Multicultural Importance: 0.0
# Variable: Field of study:.African-Americanhistory Importance: 0.0
# Variable: United States:.Orlando(+50mi)Florida Importance: 0.0
# Variable: Interests:.SecondAmendmentSisters Importance: 0.0
# Variable: Affinity:.Hispanic(US-Spanishdominant) Importance: 0.0
# Variable: Interests:.100PercentFEDUp Importance: 0.0
# Variable: United States:.NewYork(+50mi)NewYork Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoStopA.1. Importance: 0.0
# Variable: Interests:.BernieSanders Importance: 0.0
# Variable: Interests:.Indiana   Importance: 0.0
# Variable: Age:.15-54           Importance: 0.0
# Variable: Mexico.;NewYork;Oklahoma;Texas;Washington Importance: 0.0
# Variable: United States:.LongBeach(+25mi)California Importance: 0.0
# Variable: Exclude people who like.Blacktivist Importance: 0.0
# Variable: People Who Match:.Pan-Africanism Importance: 0.0
# Variable: Interests:.TheThinBlueLine Importance: 0.0
# Variable: People Who Match:.PeoplewholikeLGBTUnited. Importance: 0.0
# Variable: on pages:.NewsFeedonmobiledevices Importance: 0.0
# Variable: Interests:.Blackchurch Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoBornLiberal Importance: 0.0
# Variable: Exclude people who like.Nefertiti'sCommunity Importance: 0.0
# Variable: People Who Match:.African-Americanhistory Importance: 0.0
# Variable: Interests:.Afrocentrism Importance: 0.0
# Variable: Interests:.SecondAmendmenttotheUnitedStatesConstitution Importance: 0.0
# Variable: Interests:.BlackNews.com Importance: 0.0
# Variable: Interests:.Understandingracialsegregationintheunitedstates Importance: 0.0
# Variable: Home Composition:.Veteransinhome Importance: 0.0
# Variable: Exclude:.Hispanic(US-Bilingual:EnglishandSpanish) Importance: 0.0
# Variable: United States:.Atlanta(+25mi)Georgia;NewOrleans(+50mi)Louisiana;Baltimore(+50mi) Importance: 0.0
# Variable: Language:.NewsFeedonmobiledevices Importance: 0.0
# Variable: Interests:.Copwatch  Importance: 0.0
# Variable: United States:.NewYorkNewYork Importance: 0.0
# Variable: Exclude:.Hispanic(US-Spanishdominant) Importance: 0.0
# Variable: Interests:.BlackPantherParty Importance: 0.0
# Variable: Interests:.Entertainment Importance: 0.0
# Variable: United States:.Washington(+50mi)DistrictofColumbia Importance: 0.0
# Variable: Interests:.HartofDixie Importance: 0.0
# Variable: Interests:.ZaidShakir Importance: 0.0
# Variable: Interests:.Righttokeepandbeararms Importance: 0.0
# Variable: Interests:.Allah     Importance: 0.0
# Variable: People Who Match:.PeoplewholikeBlacktivist Importance: 0.0
# Variable: Interests:.ChicksOnTheRight Importance: 0.0
# Variable: Interests:.Humanitarianism Importance: 0.0
# Variable: Interests:.Homosexuality Importance: 0.0
# Variable: Interests:.HuffPostBlackVoices Importance: 0.0
# Variable: Custom Audience:.1%)-newtestaudit Importance: 0.0
# Variable: Interests:.As-salamualaykum Importance: 0.0
# Variable: Interests:.AbuEesaNiamatullah Importance: 0.0
# Variable: Interests:.Liberty   Importance: 0.0
# Variable: Affinity:.Hispanic(US-All) Importance: 0.0
# Variable: People Who Match:.Jr. Importance: 0.0
# Variable: Exclude people who like.Don'tShoot Importance: 0.0
# Variable: Behaviors:.Hispanic(US-Bilingual:EnglishandSpanish) Importance: 0.0
# Variable: United States:.Detroit(+70km)Michigan Importance: 0.0
# Variable: Interests:.FoxNewsChannel Importance: 0.0
# Variable: Interests:.Libertarianism Importance: 0.0
# Variable: United States:.Newark(+25mi)NewJersey;Cleveland(+25mi)Ohio;Chester(+25mi)Pennsylvania Importance: 0.0
# Variable: United States:.Alabama;Arizona;California;Florida;Georgia;Mississippi;New Importance: 0.0
# Variable: Behaviors:.Hispanic(US-Spanishdominant) Importance: 0.0
# Variable: Interests:.DisabledAmericanVeterans Importance: 0.0
# Variable: Politics:.USpolitics(veryconservative) Importance: 0.0
# Variable: Interests:.Selfdefense(UnitedStates) Importance: 0.0
# Variable: Mexico.ChicanoMovement Importance: 0.0
# Variable: United States:.Houston(+50mi)Texas Importance: 0.0
# Variable: Exclude:.AsianAmerican(US) Importance: 0.0
# Variable: Interests:.USMilitaryVeterans Importance: 0.0
# Variable: Interests:.MuhammadAli Importance: 0.0
# Variable: Interests:.PERSONAL&HOMEDEFENSE Importance: 0.0
# Variable: Interests:.NBAMemes  Importance: 0.0
# Variable: Interests:.EndSlaveryNow Importance: 0.0
# Variable: Interests:.LGBTcommunity Importance: 0.0
# Variable: United States:.Atlanta(+50km)Georgia Importance: 0.0
# Variable: Interests:.Philosophy Importance: 0.0
# Variable: Age:.15-30           Importance: 0.0
# Variable: Interests:.freemusic Importance: 0.0
# Variable: Interests:.UnitedStatesBillofRights Importance: 0.0
# Variable: People Who Match:.African-Americanhistory.MalcolmX Importance: 0.0
# Variable: Interests:.HeroesBehindTheBadge Importance: 0.0
# Variable: Interests:.Fitnessandwellness Importance: 0.0
# Variable: Interests:.Illegalimmigration Importance: 0.0
# Variable: Interests:.Foreignpolicy Importance: 0.0
# Variable: Politics:.Likelytoengagewithpoliticalcontent(conservative) Importance: 0.0
# Variable: Interests:.Equalopportunity Importance: 0.0
# Variable: Interests:.UnitedStatespresidentialelection Importance: 0.0
# Variable: Generation:.Millennials Importance: 0.0
# Variable: Interests:.AfricanNationalCongress Importance: 0.0
# Variable: Exclude people who like.Blackgunsmatter Importance: 0.0
# Variable: Interests:.MartinLutherKing.Jr.African-AmericanCivilRightsMovement(1954-68).African-Americanhistory Importance: 0.0
# Variable: Interests:.TheRawStory Importance: 0.0
# Variable: And Must Also Match:.AppleMusic Importance: 0.0
# Variable: Interests:.JulianAssange Importance: 0.0
# Variable: Exclude people who like.BrownPower Importance: 0.0
# Variable: Interests:.Patriotism Importance: 0.0
# Variable: Interests:.Independence Importance: 0.0
# Variable: Placements:.InstagramFeed Importance: 0.0
# Variable: Interests:.UnitedStatesConstitution Importance: 0.0
# Variable: Interests:.UnitedStatesDepartmentofHomelandSecurity Importance: 0.0
# Variable: People Who Match:.PeoplewholikeWilliams&Kalvin Importance: 0.0
# Variable: Exclude:.Multicultural Importance: 0.0
# Variable: Interests:.All-americanmuslimculture Importance: 0.0
# Variable: Interests:.Rightofself-defense Importance: 0.0
# Variable: Interests:.ConservatismintheUnitedStates Importance: 0.0
# Variable: Interests:.MumiaAbuJamal Importance: 0.0
# Variable: Age:.45-65+          Importance: 0.0
# Variable: School:.Riverside    Importance: 0.0
# Variable: on pages:.Rightcolumnondesktopcomputers Importance: 0.0
# Variable: Mexico.Chicano.ChicanoMovement Importance: 0.0
# Variable: Interests:.Texas     Importance: 0.0
# Variable: Interests:.Far-rightpolitics Importance: 0.0
# Variable: Interests:.Nigerians Importance: 0.0
# Variable: People Who Match:.Friendsofconnections.FriendsofpeoplewhoareconnectedtoWilliams&Kalvin Importance: 0.0
# Variable: Exclude people who like.Pan-AfricanrootsMOVE Importance: 0.0
# Variable: United States:.Atlanta(+25mi)Georgia Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoWilliams&Kalvin Importance: 0.0
# Variable: Interests:.PoliceBrutalityisaCrime Importance: 0.0
# Variable: Interests:.FlagsoftheConfederateStatesofAmerica Importance: 0.0
# Variable: United States:.Texas Importance: 0.0
# Variable: Interests:.Multicultural Importance: 0.0
# Variable: Interests:.BlackGirlsRock! Importance: 0.0
# Variable: Interests:.Anti-discrimination Importance: 0.0
# Variable: Interests:.TheSecondAmendment Importance: 0.0
# Variable: Interests:.CopBlock  Importance: 0.0
# Variable: Interests:.MemeCenter Importance: 0.0
# Variable: Interests:.GunRights Importance: 0.0
# Variable: Facebook access (browser):.Chrome Importance: 0.0
# Variable: School:.UniversityofWisconsin-Madison Importance: 0.0
# Variable: Interests:.UnitedStatesDepartmentofVeteransAffairs Importance: 0.0
# Variable: People Who Match:.PeoplewholikeLGBTUnited Importance: 0.0
# Variable: And Must Also Match:.InterestsFreesoftware Importance: 0.0
# Variable: Interests:.motherjones Importance: 0.0
# Variable: Interests:.GooglePlayMusic Importance: 0.0
# Variable: Interests:.MuslimBrotherhood Importance: 0.0
# Variable: on pages:.SuggestedVideoonmobiledevices Importance: 0.0
# Variable: Interests:.Lesbiancommunity Importance: 0.0
# Variable: People Who Match:.Blackhistory.AfricanAmericanCivilRightsMovement(1954-68) Importance: 0.0
# Variable: United States:.Detroit(+35mi)Michigan Importance: 0.0
# Variable: Mexico.ChicanoMovement.Hispanidad Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoLGBTUnited Importance: 0.0
# Variable: Interests:.Music     Importance: 0.0
# Variable: Exclude people who like.LGBTUnited Importance: 0.0
# Variable: Interests:.Anarcho-capitalism Importance: 0.0
# Variable: Age:.18-65+PlacementsNewsFeedondesktopcomputers Importance: 0.0
# Variable: Interests:.BlackEnterprise Importance: 0.0
# Variable: Interests:.Mud&Trucks Importance: 0.0
# Variable: Interests:.Mixedmartialarts Importance: 0.0
# Variable: Interests:.Politicsandsocialissues Importance: 0.0
# Variable: Location:.Germany    Importance: 0.0
# Variable: Interests:.NelsonMandela Importance: 0.0
# Variable: Interests:.Blackpanther Importance: 0.0
# Variable: Interests:.VietnamVeteransMemorialFund Importance: 0.0
# Variable: Interests:.Quran     Importance: 0.0
# Variable: Interests:.StopIllegalImmigration Importance: 0.0
# Variable: United States:.Washington Importance: 0.0
# Variable: Interests:.Politics  Importance: 0.0
# Variable: Interests:.NativeNewsOnline Importance: 0.0
# Variable: Interests:.Conservatism Importance: 0.0
# Variable: United States:.Tampa(+25mi)Florida Importance: 0.0
# Variable: United States:.Astoria(+25mi)NewYork Importance: 0.0
# Variable: Language:.Arabic     Importance: 0.0
# Variable: Interests:.Firearm   Importance: 0.0
# Variable: Interests:.Gospel    Importance: 0.0
# Variable: Age:.16-53           Importance: 0.0
# Variable: Friends of connections:.FriendsofpeoplewhoareconnectedtoBlacktivist Importance: 0.0
# Variable: Behaviors:.Multicultural Importance: 0.0
# Variable: Interests:.SyriaCharity Importance: 0.0
# Variable: Facebook access (browser):.Firefox Importance: 0.0
# Variable: Interests:.Shazam(service) Importance: 0.0
# Variable: Interests:.Pan-Africanism Importance: 0.0
# Variable: Affinity:.AsianAmerican(US) Importance: 0.0
# Variable: Exclude:.BehaviorsHispanic(US-All) Importance: 0.0
# Variable: Interests:.VietnamVeteransofAmerica Importance: 0.0
# Variable: Interests:.ProphetsandmessengersinIslam Importance: 0.0
# Variable: Interests:.Guns&Patriots Importance: 0.0
# Variable: Interests:.Syria-News Importance: 0.0
# Variable: Interests:.DonaldTrumpJr. Importance: 0.0
# Variable: Interests:.Baptism   Importance: 0.0
# Variable: Interests:.Presbyterianism Importance: 0.0
# Variable: Mexico..Latinhiphop  Importance: 0.0
# Variable: Interests:.GlossaryofIslam Importance: 0.0
# Variable: People Who Match:.Policemisconduct;African-Americanculture;African-AmericanCivilRightsMovement(1954-68) Importance: 0.0
# Variable: Interests:.SecondAmendmentSupporters Importance: 0.0
# Variable: United States:.DetroitMichigan Importance: 0.0
# Variable: Interests:.BlackTeaPatriots Importance: 0.0
# Variable: Interests:.BlackBusinessBuildersClub Importance: 0.0
# Variable: Interests:.Cherokeelanguage Importance: 0.0
# Variable: Interests:.Hobbiesandactivities Importance: 0.0
# Variable: Interests:.NationalMuseumofAmericanHistory;MayaAngelou Importance: 0.0
# Variable: Age:.18-60           Importance: 0.0
# Variable: Age:.13-30           Importance: 0.0
# Variable: Age:.18-54           Importance: 0.0
# Variable: Interests:.NationalMuseumofAmericanHistory Importance: 0.0
# Variable: Interests:.OurWorldwithBlackEnterprise Importance: 0.0
# Variable: United States:.Chester(+20km)Arkansas;Washington(+20km)DistrictofColumbia;Atlanta(+20km)Georgia;NewOrleans(+20km)Louisiana;Baltimore(+20km)Maryland;St.Louis(+20km)Missouri;Cleveland(+20km)Ohio;Philadelphia(+20km)Pennsylvania;Memphis(+20km)Tennessee;Richmond(+20km)Virginia;Milwaukee(+20km)Wisconsin Importance: 0.0
# Variable: Interests:.Blackisbeautiful Importance: 0.0
# Variable: Interests:.ActiveSelfProtection Importance: 0.0
# Variable: Interests:.MedgarEvers Importance: 0.0
# Variable: Interests:.DonaldTrumpforPresident Importance: 0.0
# Variable: Interests:.BuzzFeed  Importance: 0.0
# Variable: Interests:.AnythingAboutGuns Importance: 0.0
# Variable: Interests:.RomanCatholicdevotions Importance: 0.0
# Variable: Interests:.Love      Importance: 0.0
# Variable: Interests:.MyBlackisBeautiful Importance: 0.0
# Variable: Interests:.Rockmusic Importance: 0.0
# Variable: Interests:.StopPoliceBrutality Importance: 0.0
# Variable: Interests:.Immigration Importance: 0.0
# Variable: United States:.St.LouisMissouri:ClevelandOhio Importance: 0.0
# Variable: Interests:.Welfarestate Importance: 0.0
# Variable: Mexico.Hispanicculture Importance: 0.0
# Variable: Interests:.AppleMusic Importance: 0.0
# Variable: Interests:.Kemetism  Importance: 0.0
# Variable: Facebook access (mobile):.allmobiledevices Importance: 0.0
# Variable: Gender:.Female       Importance: 0.0
# Variable: Age:.16-40           Importance: 0.0
# Variable: United States:.BaltimoreMaryland;Ferguson Importance: 0.0
# Variable: on pages:.InstagramFeed Importance: 0.0
# Variable: behavior_sunday      Importance: 0.0
# Variable: behavior_monday      Importance: 0.0
# Variable: behavior_tuesday     Importance: 0.0
# Variable: behavior_wednesday   Importance: 0.0
# Variable: behavior_thursday    Importance: 0.0
# Variable: behavior_friday      Importance: 0.0
# Variable: behavior_saturday    Importance: 0.0
# Variable: behavior_0000        Importance: 0.0
# Variable: behavior_0100        Importance: 0.0
# Variable: behavior_0200        Importance: 0.0
# Variable: behavior_0300        Importance: 0.0
# Variable: behavior_0400        Importance: 0.0
# Variable: behavior_0500        Importance: 0.0
# Variable: behavior_0600        Importance: 0.0
# Variable: behavior_0700        Importance: 0.0
# Variable: behavior_0800        Importance: 0.0
# Variable: behavior_0900        Importance: 0.0
# Variable: behavior_1000        Importance: 0.0
# Variable: behavior_1100        Importance: 0.0
# Variable: behavior_1200        Importance: 0.0
# Variable: behavior_1300        Importance: 0.0
# Variable: behavior_1400        Importance: 0.0
# Variable: behavior_1500        Importance: 0.0
# Variable: behavior_1600        Importance: 0.0
# Variable: behavior_1700        Importance: 0.0
# Variable: behavior_1800        Importance: 0.0
# Variable: behavior_1900        Importance: 0.0
# Variable: behavior_2000        Importance: 0.0
# Variable: behavior_2100        Importance: 0.0
# Variable: behavior_2200        Importance: 0.0
# Variable: behavior_2300        Importance: 0.0
# Variable: processed_language   Importance: 0.0
# Variable: big5_agreeableness_significant Importance: 0.0
# Variable: facet_altruism_significant Importance: 0.0
# Variable: facet_cooperation_significant Importance: 0.0
# Variable: facet_modesty_significant Importance: 0.0
# Variable: facet_morality_significant Importance: 0.0
# Variable: facet_sympathy_significant Importance: 0.0
# Variable: facet_trust_significant Importance: 0.0
# Variable: big5_conscientiousness_significant Importance: 0.0
# Variable: facet_achievement_striving_significant Importance: 0.0
# Variable: facet_cautiousness_significant Importance: 0.0
# Variable: facet_dutifulness_significant Importance: 0.0
# Variable: facet_orderliness_significant Importance: 0.0
# Variable: facet_self_discipline_significant Importance: 0.0
# Variable: facet_self_efficacy_significant Importance: 0.0
# Variable: big5_extraversion_significant Importance: 0.0
# Variable: facet_activity_level_significant Importance: 0.0
# Variable: facet_assertiveness_significant Importance: 0.0
# Variable: facet_cheerfulness_significant Importance: 0.0
# Variable: facet_excitement_seeking_significant Importance: 0.0
# Variable: facet_friendliness_significant Importance: 0.0
# Variable: facet_gregariousness_significant Importance: 0.0
# Variable: big5_neuroticism_significant Importance: 0.0
# Variable: facet_anger_significant Importance: 0.0
# Variable: facet_anxiety_significant Importance: 0.0
# Variable: facet_depression_significant Importance: 0.0
# Variable: facet_immoderation_significant Importance: 0.0
# Variable: facet_self_consciousness_significant Importance: 0.0
# Variable: facet_vulnerability_significant Importance: 0.0
# Variable: big5_openness_significant Importance: 0.0
# Variable: facet_adventurousness_significant Importance: 0.0
# Variable: facet_artistic_interests_significant Importance: 0.0
# Variable: facet_emotionality_significant Importance: 0.0
# Variable: facet_imagination_significant Importance: 0.0
# Variable: facet_intellect_significant Importance: 0.0
# Variable: facet_liberalism_significant Importance: 0.0
# Variable: need_liberty_significant Importance: 0.0
# Variable: need_ideal_significant Importance: 0.0
# Variable: need_love_significant Importance: 0.0
# Variable: need_practicality_significant Importance: 0.0
# Variable: need_self_expression_significant Importance: 0.0
# Variable: need_stability_significant Importance: 0.0
# Variable: need_structure_significant Importance: 0.0
# Variable: need_challenge_significant Importance: 0.0
# Variable: need_closeness_significant Importance: 0.0
# Variable: need_curiosity_significant Importance: 0.0
# Variable: need_excitement_significant Importance: 0.0
# Variable: need_harmony_significant Importance: 0.0
# Variable: value_conservation_significant Importance: 0.0
# Variable: value_hedonism_significant Importance: 0.0
# Variable: value_openness_to_change_significant Importance: 0.0
# Variable: value_self_enhancement_significant Importance: 0.0
# Variable: racist               Importance: 0.0
# Variable: american             Importance: 0.0
# Variable: white                Importance: 0.0
# Variable: democrat             Importance: 0.0
# Variable: gun                  Importance: 0.0
# Variable: islam                Importance: 0.0
# Variable: gay                  Importance: 0.0
# Variable: rally                Importance: 0.0
# Variable: gender               Importance: 0.0
# Variable: brown                Importance: 0.0
# Variable: Jesus                Importance: 0.0
# Variable: ISIS                 Importance: 0.0
# Variable: Trump                Importance: 0.0
# Variable: immigrant            Importance: 0.0
# Variable: mm_yyyy_10_2015      Importance: 0.0
# Variable: mm_yyyy_12_2015      Importance: 0.0
# Variable: mm_yyyy_12_2016      Importance: 0.0
# Variable: mm_yyyy_1_2016       Importance: 0.0
# Variable: mm_yyyy_1_2017       Importance: 0.0
# Variable: mm_yyyy_3_2016       Importance: 0.0
# Variable: mm_yyyy_6_2016       Importance: 0.0
# Variable: mm_yyyy_7_2015       Importance: 0.0
# Variable: mm_yyyy_7_2017       Importance: 0.0
# Variable: mm_yyyy_8_2015       Importance: 0.0
# Variable: mm_yyyy_8_2016       Importance: 0.0
# Variable: mm_yyyy_8_2017       Importance: 0.0
# Variable: mm_yyyy_9_2015       Importance: 0.0
# Variable: mm_yyyy_9_2016       Importance: 0.0
# Variable: medium_Facebook      Importance: 0.0
# Variable: medium_Instagram     Importance: 0.0
# Variable: month_1              Importance: 0.0
# Variable: month_6              Importance: 0.0
# Variable: month_7              Importance: 0.0
# Variable: month_8              Importance: 0.0
# Variable: month_9              Importance: 0.0
# Variable: month_12             Importance: 0.0
